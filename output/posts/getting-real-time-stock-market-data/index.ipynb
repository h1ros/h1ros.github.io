# %% [markdown]
# # Goal
# This post aims to introduce how to get **real time stock market data** using Google API.
#
# **Reference**
# * [How can I get real time stock market data for use in a Python program?](https://www.quora.com/How-can-I-get-real-time-stock-market-data-for-use-in-a-Python-program)
# * [Google Finance API and Its Alternatives](https://blog.rapidapi.com/google-finance-api-alternatives/)

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import quandl

# %% [markdown]
# # Get real time stock price data
#
# ## Create a class `GoogleFinanceAPI`
# Overall flow of the following class `GoogleFinanceAPI`:
# 1. Initialization - set google finance API url as member `prefix`
# 2. `get` method
#     * create url with input argument `symbol` i.e., stock name and `exchange` i.e., the place of stock market
#     * make a rest request call by using `urllib`
#     * decode and parse the response from api

# %%
mydata = quandl.get(["WIKI/AAPL"])

# %%
mydata
# Out:
#             WIKI/AAPL - Open  WIKI/AAPL - High  WIKI/AAPL - Low  \
# Date
# 1980-12-12            28.750            28.870          28.7500
# 1980-12-15            27.380            27.380          27.2500
# 1980-12-16            25.370            25.370          25.2500
# 1980-12-17            25.870            26.000          25.8700
# 1980-12-18            26.630            26.750          26.6300
# 1980-12-19            28.250            28.380          28.2500
# 1980-12-22            29.630            29.750          29.6300
# 1980-12-23            30.880            31.000          30.8800
# 1980-12-24            32.500            32.630          32.5000
# 1980-12-26            35.500            35.620          35.5000
# 1980-12-29            36.000            36.130          36.0000
# 1980-12-30            35.250            35.250          35.1200
# 1980-12-31            34.250            34.250          34.1300
# 1981-01-02            34.500            34.750          34.5000
# ...

# %%
response = requests.post("https://apidojo-yahoo-finance-v1.p.rapidapi.com/market/get-summary?region=US&lang=en",
    headers={
    "X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com",
    "X-RapidAPI-Key": "9a7613bd82msh659031e18de09b4p1a80eejsnc404face8431"
  })

response
# Out:
# <Response [403]>

# %%
req = urllib.request.Request(url="https://apidojo-yahoo-finance-v1.p.rapidapi.com/market/get-quotes?region=US&lang=en&symbols=BAC%2CKC%3DF%2C002210.KS%2CIWM%2CAMECX", 
headers={
    "X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com",
    "X-RapidAPI-Key": "9a7613bd82msh659031e18de09b4p1a80eejsnc404face8431"
  }
)

req

# %%
response = unirest.get("https://apidojo-yahoo-finance-v1.p.rapidapi.com/market/get-charts?comparisons=%5EGDAXI%2C%5EFCHI&region=US&lang=en&symbol=HYDR.ME&interval=5m&range=1d",
  headers={
    "X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com",
    "X-RapidAPI-Key": "9a7613bd82msh659031e18de09b4p1a80eejsnc404face8431"
  }
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f9a872e49de8> in <module>
# ----> 1 response = unirest.get("https://apidojo-yahoo-finance-v1.p.rapidapi.com/market/get-charts?comparisons=%5EGDAXI%2C%5EFCHI&region=US&lang=en&symbol=HYDR.ME&interval=5m&range=1d",
#       2   headers={
#       3     "X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com",
#       4     "X-RapidAPI-Key": "9a7613bd82msh659031e18de09b4p1a80eejsnc404face8431"
#       5   }
#
# NameError: name 'unirest' is not defined

# %%
class GoogleFinanceAPI:
    """Get the real time stock data using google finance API.
    """
    def __init__(self):
        self.prefix = "https://finance.google.com/finance/info?client=ig&q="

    def get(self, symbol, exchange):
        url = self.prefix + "%s:%s" % (exchange, symbol)
        u = urllib.request.urlopen(url)
        content = u.read().decode('utf-8')
        obj = json.loads(content[3:])
        return obj[0]

# %% [markdown]
# ## Execute `GoogleFinanceAPI`

# %%
 c = GoogleFinanceAPI()
quote = c.get("RELIANCE","NSE")
print(quote)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-fb4ed49c2548> in <module>
#       1 c = GoogleFinanceAPI()
# ----> 2 quote = c.get("RELIANCE","NSE")
#       3 print(quote)
#
# <ipython-input-4-ce974c1322d2> in get(self, symbol, exchange)
#       7     def get(self, symbol, exchange):
#       8         url = self.prefix + "%s:%s" % (exchange, symbol)
# ----> 9         u = urllib.request.urlopen(url)
#      10         content = u.read().decode('utf-8')
#      11         obj = json.loads(content[3:])
#
# ~/anaconda3/envs/py367/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ...
