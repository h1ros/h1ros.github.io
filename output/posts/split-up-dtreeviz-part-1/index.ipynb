# %% [markdown]
# # Goal
# In this post, we will go through each function in [`dtreeviz`](https://github.com/parrt/dtreeviz) module  to fully understand what is implemented. After fully understanding this, I would like to contribute to this module and submit a pull request.
#
# I really like this module and would like to see this works for other tree-based modules like XGBoost or Lightgbm. I found [the exact same issue (issues 15)](https://github.com/parrt/dtreeviz/issues/15) in github so I hope I could contribute to this issue.
#
# > You would just have to get ShadowDecisionTree wrappers for those trees.
#
# Based on this comment, I need first understand the class object `ShadowDecisionTree`
#
# ![image](https://user-images.githubusercontent.com/8764683/56184236-40687500-5fce-11e9-8e82-922cb1c7cd20.png)

# %% [markdown]
# # Understand folder structure
# In this post, we will deep dive into the core module `dtreeviz`
# ![image](https://user-images.githubusercontent.com/8764683/56184705-eb2d6300-5fcf-11e9-9111-83f79f5c34f7.png)
#
# This module comprises of 4 python files.
# ![image](https://user-images.githubusercontent.com/8764683/56184787-3778a300-5fd0-11e9-9835-c837080de3cd.png)
#
# `__init__.py` is empty so we can skip it.
#
# Let's see one by one.

# %% [markdown]
# <!-- TEASER_END -->

# %% [markdown]
# # `dtreeviz` Module
# ## `shadow.py`
#
# `shadow` module contains two class objects:
# * `ShadowDecTree`
# * `ShadowDecTreeNode`

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/8764683/56185213-b91d0080-5fd1-11e9-9c5a-2eefdc1db5b2.png)
#
# ![image](https://user-images.githubusercontent.com/8764683/56185143-85da7180-5fd1-11e9-91c2-2711fcaab20d.png)

# %% [markdown]
# Since `ShadowDecTreeNode` take shadow_tree object as one of the input argument, we can first look at `ShadowDecTree`.
#
# ![image](https://user-images.githubusercontent.com/8764683/56185634-5ed06f80-5fd2-11e9-950a-42a03bd8abd5.png)

# %% [markdown]
# ### `ShadowDecTree`
#
# #### Attributes
#
# There are 12 class attributes in `ShadowDecTree`.

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/8764683/56187541-c4732a80-5fd7-11e9-93a6-7480cd1f7f6f.png)

# %% [markdown]
# `tree_model`, `feature_names`, `class_names`, `class_weight`, `X_train`, `y_train` is just passed from input arguments and inherited from decision tree object e.g., scikit-learn decision tree. `class_names` might be updated when the number of class is more than 2.
#
# ```python
#         self.tree_model = tree_model
#         self.feature_names = feature_names
#         self.class_names = class_names
#         self.class_weight = tree_model.class_weight
#         # Omit the lines
#         self.X_train = X_train
#         self.y_train = y_train
#
# ```
#
# * `root` is a root `ShadowDecTreeNode`
# * `internal` and `leaves` are a list of `ShadowDecTreeNode` generated by a function `walk`.
#
# `node_to_samples` and `unique_target_values`

# %% [markdown]
# To be continued....
