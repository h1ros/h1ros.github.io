# %% [markdown]
# # How to use Keras
#
# Keras is human-readable wrapper for deep learning. This tutorial is meant for those who never touched deep learning modules e.g., tensolflow, torch, or caffe.
#
#
# ## Getting started
# Before going to the detail, let's just run it and see it.
#
# ### Pre-requisite
# python 2 or 3 with anaconda and tensolflow are required to follow this tutorial. Please refer to this to set up your environment.
#
# [How to setup a python Environment for Deep Learning](http://localhost:8888/?token=a1c6abc4a5cdafd2f1155c80b79db5704e0ca78e9e9d14db)
#
# ## Data Preparation

# %%
import pandas as pd
import matplotlib.pyplot as plt
# import cufflinks
# %matplotlib inline

# %%
path_data = "data/international-airline-passengers.csv"
df_airplane = pd.read_csv(path_data)

df_airplane.head()
# Out:
#      Month  \
# 0  1949-01
# 1  1949-02
# 2  1949-03
# 3  1949-04
# 4  1949-05
#
#    International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                              112.0
# 1                                              118.0
# 2                                              132.0
# 3                                              129.0
# 4                                              121.0

# %%
df_airplane.dtypes
# Out:
# Month                                                                              object
# International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60    float64
# dtype: object

# %%
# Plot raw data
ax = df_airplane.set_index('Month').plot(figsize=(16, 7))
