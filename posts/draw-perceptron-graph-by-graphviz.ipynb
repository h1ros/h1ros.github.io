# %% [markdown]
# # Goal
#
# This post aims to introduce how to draw a diagram for perceptron.
#
#
# **Reference**
# * [Step-by-step Data Science - Implement Perceptron](https://h1ros.github.io/posts/implement-perceptron/)

# %% [markdown]
# # Libraries

# %%
from graphviz import Digraph

# %% [markdown]
# # Create a node list and dictionary for the edges

# %%
# List of nodes
l_nodes = ['1', 'x0', 'x1', 'y']

# Dictionary mapping from label name to the edge between two nodes
d_edges = {'b': ('1', 'y'), 
           'w0': ('x0', 'y'), 
           'w1': ('x1', 'y')}

# %% [markdown]
# # Visualize a graph for perceptron

# %%
# Create Digraph object
dot = Digraph()
dot.attr(rankdir='LR')

# Add nodes
for n in l_nodes:
    dot.node(n)        

# Add edges
for label, edges in d_edges.items(): 
    dot.edge(edges[0], edges[1], label=label)

# Fill node 1 by gray
dot.node('1', style='filled')
    
# Visualize the graph
dot
